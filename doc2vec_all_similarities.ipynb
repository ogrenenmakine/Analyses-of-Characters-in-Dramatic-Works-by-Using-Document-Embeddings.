# %%
# %matplotlib inline

# %% [markdown]
# Doc2Vec Model
# =============

# %%
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
import os
import gensim
from sklearn import metrics
import numpy as np
import seaborn as sns; sns.set()
from matplotlib import pyplot
# Set file names for train and test data
train_file = os.path.join('data/all.txt')

# %% [markdown]
# Define a Function to Read and Preprocess Text
# ---------------------------------------------
#
# Below, we define a function to:
#
# - open the train/test file (with latin encoding)
# - read the file line-by-line
# - pre-process each line (tokenize text into individual words, remove punctuation, set to lowercase, etc)
#
# The file we're reading is a **corpus**.
# Each line of the file is a **document**.
#
# .. Important::
#   To train the model, we'll need to associate a tag/number with each document
#   of the training corpus. In our case, the tag is simply the zero-based line
#   number.

# %%
import smart_open

def read_corpus(fname, tokens_only=False):
    with smart_open.open(fname, encoding="iso-8859-1") as f:
        for i, line in enumerate(f):
            tokens = gensim.utils.simple_preprocess(line)
            if tokens_only:
                yield tokens
            else:
                # For training data, add tags
                yield gensim.models.doc2vec.TaggedDocument(tokens, [i])

train_corpus = list(read_corpus(train_file))

# %% [markdown]
# Training the Model
# ------------------
#
# Now, we'll instantiate a Doc2Vec model with a vector size with 50 dimensions and
# iterating over the training corpus 40 times. We set the minimum word count to
# 2 in order to discard words with very few occurrences. (Without a variety of
# representative examples, retaining such infrequent words can often make a
# model worse!) Typical iteration counts in the published `Paragraph Vector paper <https://cs.stanford.edu/~quocle/paragraph_vector.pdf>`__
# results, using 10s-of-thousands to millions of docs, are 10-20. More
# iterations take more time and eventually reach a point of diminishing
# returns.
#
# However, this is a very very small dataset (300 documents) with shortish
# documents (a few hundred words). Adding training passes can sometimes help
# with such small datasets.

# %%
model = gensim.models.doc2vec.Doc2Vec(vector_size=50, min_count=2, epochs=40)
# Out:
# 2019-11-22 08:49:58,372 : WARNING : consider setting layer size to a multiple of 4 for greater performance

# %% [markdown]
# Build a vocabulary

# %%
model.build_vocab(train_corpus)
# Out:
# 2019-11-22 08:49:58,387 : INFO : collecting all words and their counts
# 2019-11-22 08:49:58,387 : INFO : PROGRESS: at example #0, processed 0 words (0/s), 0 word types, 0 tags
# 2019-11-22 08:49:58,472 : INFO : collected 22668 word types and 37 unique tags from a corpus of 37 examples and 777116 words
# 2019-11-22 08:49:58,473 : INFO : Loading a fresh vocabulary
# 2019-11-22 08:49:58,505 : INFO : effective_min_count=2 retains 14306 unique words (63% of original 22668, drops 8362)
# 2019-11-22 08:49:58,505 : INFO : effective_min_count=2 leaves 768754 word corpus (98% of original 777116, drops 8362)
# 2019-11-22 08:49:58,534 : INFO : deleting the raw counts dictionary of 22668 items
# 2019-11-22 08:49:58,534 : INFO : sample=0.001 downsamples 62 most-common words
# 2019-11-22 08:49:58,535 : INFO : downsampling leaves estimated 581967 word corpus (75.7% of prior 768754)
# 2019-11-22 08:49:58,560 : INFO : estimated required memory for 14306 words and 50 dimensions: 12882800 bytes
# 2019-11-22 08:49:58,561 : INFO : resetting layer weights

# %% [markdown]
# Essentially, the vocabulary is a dictionary (accessible via
# ``model.wv.vocab``\ ) of all of the unique words extracted from the training
# corpus along with the count (e.g., ``model.wv.vocab['penalty'].count`` for
# counts for the word ``penalty``\ ).

# %% [markdown]
# Next, train the model on the corpus.
# If the BLAS library is being used, this should take no more than 3 seconds.
# If the BLAS library is not being used, this should take no more than 2
# minutes, so use BLAS if you value your time.

# %%
model.train(train_corpus, total_examples=model.corpus_count, epochs=model.epochs)
# Out:
# 2019-11-22 08:50:00,439 : INFO : training model with 3 workers on 14306 vocabulary and 50 features, using sg=0 hs=0 sample=0.001 negative=5 window=5
# 2019-11-22 08:50:00,668 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-22 08:50:00,676 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-22 08:50:00,681 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-22 08:50:00,681 : INFO : EPOCH - 1 : training on 777116 raw words (370037 effective words) took 0.2s, 1559247 effective words/s
# 2019-11-22 08:50:00,854 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-22 08:50:00,858 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-22 08:50:00,866 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-22 08:50:00,866 : INFO : EPOCH - 2 : training on 777116 raw words (370037 effective words) took 0.2s, 2036055 effective words/s
# 2019-11-22 08:50:01,040 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-22 08:50:01,043 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-22 08:50:01,049 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-22 08:50:01,050 : INFO : EPOCH - 3 : training on 777116 raw words (370037 effective words) took 0.2s, 2059106 effective words/s
# 2019-11-22 08:50:01,236 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-22 08:50:01,241 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-22 08:50:01,243 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-22 08:50:01,244 : INFO : EPOCH - 4 : training on 777116 raw words (370037 effective words) took 0.2s, 1919921 effective words/s
# 2019-11-22 08:50:01,416 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-22 08:50:01,420 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-22 08:50:01,424 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-22 08:50:01,424 : INFO : EPOCH - 5 : training on 777116 raw words (370037 effective words) took 0.2s, 2088506 effective words/s
# 2019-11-22 08:50:01,598 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-22 08:50:01,601 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-22 08:50:01,607 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-22 08:50:01,608 : INFO : EPOCH - 6 : training on 777116 raw words (370037 effective words) took 0.2s, 2033577 effective words/s
# 2019-11-22 08:50:01,787 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-22 08:50:01,790 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-22 08:50:01,793 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-22 08:50:01,794 : INFO : EPOCH - 7 : training on 777116 raw words (370037 effective words) took 0.2s, 2038112 effective words/s
# 2019-11-22 08:50:01,978 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-22 08:50:01,980 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-22 08:50:01,993 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-22 08:50:01,994 : INFO : EPOCH - 8 : training on 777116 raw words (370037 effective words) took 0.2s, 1873752 effective words/s
# 2019-11-22 08:50:02,190 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-22 08:50:02,193 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-22 08:50:02,196 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-22 08:50:02,196 : INFO : EPOCH - 9 : training on 777116 raw words (370037 effective words) took 0.2s, 1844874 effective words/s
# 2019-11-22 08:50:02,400 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-22 08:50:02,404 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-22 08:50:02,413 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-22 08:50:02,413 : INFO : EPOCH - 10 : training on 777116 raw words (370037 effective words) took 0.2s, 1721651 effective words/s
# 2019-11-22 08:50:02,595 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-22 08:50:02,598 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-22 08:50:02,605 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-22 08:50:02,605 : INFO : EPOCH - 11 : training on 777116 raw words (370037 effective words) took 0.2s, 1974659 effective words/s
# 2019-11-22 08:50:02,787 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-22 08:50:02,793 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-22 08:50:02,796 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-22 08:50:02,796 : INFO : EPOCH - 12 : training on 777116 raw words (370037 effective words) took 0.2s, 1985137 effective words/s
# 2019-11-22 08:50:02,973 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-22 08:50:02,979 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-22 08:50:02,982 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-22 08:50:02,983 : INFO : EPOCH - 13 : training on 777116 raw words (370037 effective words) took 0.2s, 2029933 effective words/s
# 2019-11-22 08:50:03,157 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-22 08:50:03,161 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-22 08:50:03,164 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-22 08:50:03,165 : INFO : EPOCH - 14 : training on 777116 raw words (370037 effective words) took 0.2s, 2054843 effective words/s
# 2019-11-22 08:50:03,344 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-22 08:50:03,347 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-22 08:50:03,350 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-22 08:50:03,350 : INFO : EPOCH - 15 : training on 777116 raw words (370037 effective words) took 0.2s, 2010464 effective words/s
# 2019-11-22 08:50:03,527 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-22 08:50:03,530 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-22 08:50:03,535 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-22 08:50:03,536 : INFO : EPOCH - 16 : training on 777116 raw words (370037 effective words) took 0.2s, 2031762 effective words/s
# 2019-11-22 08:50:03,730 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-22 08:50:03,733 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-22 08:50:03,737 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-22 08:50:03,737 : INFO : EPOCH - 17 : training on 777116 raw words (370037 effective words) took 0.2s, 1851110 effective words/s
# 2019-11-22 08:50:03,914 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-22 08:50:03,917 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-22 08:50:03,922 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-22 08:50:03,922 : INFO : EPOCH - 18 : training on 777116 raw words (370037 effective words) took 0.2s, 2026977 effective words/s
# 2019-11-22 08:50:04,097 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-22 08:50:04,100 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-22 08:50:04,109 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-22 08:50:04,109 : INFO : EPOCH - 19 : training on 777116 raw words (370037 effective words) took 0.2s, 1991445 effective words/s
# 2019-11-22 08:50:04,286 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-22 08:50:04,290 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-22 08:50:04,293 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-22 08:50:04,293 : INFO : EPOCH - 20 : training on 777116 raw words (370037 effective words) took 0.2s, 2036194 effective words/s
# 2019-11-22 08:50:04,492 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-22 08:50:04,496 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-22 08:50:04,498 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-22 08:50:04,499 : INFO : EPOCH - 21 : training on 777116 raw words (370037 effective words) took 0.2s, 1830526 effective words/s
# 2019-11-22 08:50:04,680 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-22 08:50:04,683 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-22 08:50:04,692 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-22 08:50:04,693 : INFO : EPOCH - 22 : training on 777116 raw words (370037 effective words) took 0.2s, 1921792 effective words/s
# 2019-11-22 08:50:04,868 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-22 08:50:04,871 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-22 08:50:04,875 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-22 08:50:04,875 : INFO : EPOCH - 23 : training on 777116 raw words (370037 effective words) took 0.2s, 2047547 effective words/s
# 2019-11-22 08:50:05,048 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-22 08:50:05,052 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-22 08:50:05,057 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-22 08:50:05,058 : INFO : EPOCH - 24 : training on 777116 raw words (370037 effective words) took 0.2s, 2041364 effective words/s
# 2019-11-22 08:50:05,236 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-22 08:50:05,244 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-22 08:50:05,247 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-22 08:50:05,247 : INFO : EPOCH - 25 : training on 777116 raw words (370037 effective words) took 0.2s, 1996445 effective words/s
# 2019-11-22 08:50:05,425 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-22 08:50:05,428 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-22 08:50:05,437 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-22 08:50:05,437 : INFO : EPOCH - 26 : training on 777116 raw words (370037 effective words) took 0.2s, 1967176 effective words/s
# 2019-11-22 08:50:05,617 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-22 08:50:05,620 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-22 08:50:05,629 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-22 08:50:05,629 : INFO : EPOCH - 27 : training on 777116 raw words (370037 effective words) took 0.2s, 1962426 effective words/s
# 2019-11-22 08:50:05,803 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-22 08:50:05,806 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-22 08:50:05,812 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-22 08:50:05,813 : INFO : EPOCH - 28 : training on 777116 raw words (370037 effective words) took 0.2s, 2056070 effective words/s
# 2019-11-22 08:50:05,994 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-22 08:50:05,997 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-22 08:50:06,000 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-22 08:50:06,001 : INFO : EPOCH - 29 : training on 777116 raw words (370037 effective words) took 0.2s, 1983414 effective words/s
# 2019-11-22 08:50:06,172 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-22 08:50:06,176 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-22 08:50:06,183 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-22 08:50:06,184 : INFO : EPOCH - 30 : training on 777116 raw words (370037 effective words) took 0.2s, 2044484 effective words/s
# 2019-11-22 08:50:06,396 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-22 08:50:06,396 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-22 08:50:06,403 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-22 08:50:06,404 : INFO : EPOCH - 31 : training on 777116 raw words (370037 effective words) took 0.2s, 1691953 effective words/s
# 2019-11-22 08:50:06,583 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-22 08:50:06,586 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-22 08:50:06,589 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-22 08:50:06,589 : INFO : EPOCH - 32 : training on 777116 raw words (370037 effective words) took 0.2s, 2030010 effective words/s
# 2019-11-22 08:50:06,766 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-22 08:50:06,771 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-22 08:50:06,773 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-22 08:50:06,774 : INFO : EPOCH - 33 : training on 777116 raw words (370037 effective words) took 0.2s, 2050876 effective words/s
# 2019-11-22 08:50:06,973 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-22 08:50:06,977 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-22 08:50:06,981 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-22 08:50:06,981 : INFO : EPOCH - 34 : training on 777116 raw words (370037 effective words) took 0.2s, 1798742 effective words/s
# 2019-11-22 08:50:07,179 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-22 08:50:07,182 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-22 08:50:07,185 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-22 08:50:07,185 : INFO : EPOCH - 35 : training on 777116 raw words (370037 effective words) took 0.2s, 1845453 effective words/s
# 2019-11-22 08:50:07,368 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-22 08:50:07,376 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-22 08:50:07,379 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-22 08:50:07,380 : INFO : EPOCH - 36 : training on 777116 raw words (370037 effective words) took 0.2s, 1939502 effective words/s
# 2019-11-22 08:50:07,565 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-22 08:50:07,570 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-22 08:50:07,576 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-22 08:50:07,576 : INFO : EPOCH - 37 : training on 777116 raw words (370037 effective words) took 0.2s, 1901317 effective words/s
# 2019-11-22 08:50:07,759 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-22 08:50:07,763 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-22 08:50:07,771 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-22 08:50:07,771 : INFO : EPOCH - 38 : training on 777116 raw words (370037 effective words) took 0.2s, 1941760 effective words/s
# 2019-11-22 08:50:08,002 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-22 08:50:08,008 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-22 08:50:08,014 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-22 08:50:08,015 : INFO : EPOCH - 39 : training on 777116 raw words (370037 effective words) took 0.2s, 1540404 effective words/s
# 2019-11-22 08:50:08,188 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-22 08:50:08,191 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-22 08:50:08,194 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-22 08:50:08,194 : INFO : EPOCH - 40 : training on 777116 raw words (370037 effective words) took 0.2s, 2099283 effective words/s
# 2019-11-22 08:50:08,195 : INFO : training on a 31084640 raw words (14801480 effective words) took 7.8s, 1908527 effective words/s

# %% [markdown]
# Now, we can use the trained model to infer a vector for any piece of text
# by passing a list of words to the ``model.infer_vector`` function. This
# vector can then be compared with other vectors via cosine similarity.

# %%
with open('data/All\'s Well That Ends Well/all.log') as f:
    lines = f.readlines()

similarity_matrix = np.zeros([len(lines),len(lines)])
for i in range(len(lines)):
    for j in range(len(lines)):
        similarity_matrix[i,j] = metrics.pairwise.cosine_similarity(model.infer_vector(lines[i].split()).reshape(1, -1),model.infer_vector(lines[j].split()).reshape(1, -1))

pyplot.figure(figsize=(15, 15)) # width and height in inches
sns.heatmap(similarity_matrix, cbar = True,  square = True, annot=False,annot_kws={'size': 15},  cmap= 'coolwarm')

# %%
with open('data/A Midsummer Night\'s Dream/all.log') as f:
    lines = f.readlines()

similarity_matrix = np.zeros([len(lines),len(lines)])
for i in range(len(lines)):
    for j in range(len(lines)):
        similarity_matrix[i,j] = metrics.pairwise.cosine_similarity(model.infer_vector(lines[i].split()).reshape(1, -1),model.infer_vector(lines[j].split()).reshape(1, -1))

pyplot.figure(figsize=(15, 15)) # width and height in inches
sns.heatmap(similarity_matrix, cbar = True,  square = True, annot=False,annot_kws={'size': 15},  cmap= 'coolwarm')

# %%
with open('data/As You Like It/all.log') as f:
    lines = f.readlines()

similarity_matrix = np.zeros([len(lines),len(lines)])
for i in range(len(lines)):
    for j in range(len(lines)):
        similarity_matrix[i,j] = metrics.pairwise.cosine_similarity(model.infer_vector(lines[i].split()).reshape(1, -1),model.infer_vector(lines[j].split()).reshape(1, -1))

pyplot.figure(figsize=(15, 15)) # width and height in inches
sns.heatmap(similarity_matrix, cbar = True,  square = True, annot=False,annot_kws={'size': 15},  cmap= 'coolwarm')

# %%
with open('data/Cymbeline/all.log') as f:
    lines = f.readlines()

similarity_matrix = np.zeros([len(lines),len(lines)])
for i in range(len(lines)):
    for j in range(len(lines)):
        similarity_matrix[i,j] = metrics.pairwise.cosine_similarity(model.infer_vector(lines[i].split()).reshape(1, -1),model.infer_vector(lines[j].split()).reshape(1, -1))

pyplot.figure(figsize=(15, 15)) # width and height in inches
sns.heatmap(similarity_matrix, cbar = True,  square = True, annot=False,annot_kws={'size': 15},  cmap= 'coolwarm')

# %%
with open('data/Love\'s Labour\'s Lost/all.log') as f:
    lines = f.readlines()

similarity_matrix = np.zeros([len(lines),len(lines)])
for i in range(len(lines)):
    for j in range(len(lines)):
        similarity_matrix[i,j] = metrics.pairwise.cosine_similarity(model.infer_vector(lines[i].split()).reshape(1, -1),model.infer_vector(lines[j].split()).reshape(1, -1))

pyplot.figure(figsize=(15, 15)) # width and height in inches
sns.heatmap(similarity_matrix, cbar = True,  square = True, annot=False,annot_kws={'size': 15},  cmap= 'coolwarm')

# %%
with open('data/Measure for Measure/all.log') as f:
    lines = f.readlines()

similarity_matrix = np.zeros([len(lines),len(lines)])
for i in range(len(lines)):
    for j in range(len(lines)):
        similarity_matrix[i,j] = metrics.pairwise.cosine_similarity(model.infer_vector(lines[i].split()).reshape(1, -1),model.infer_vector(lines[j].split()).reshape(1, -1))

pyplot.figure(figsize=(15, 15)) # width and height in inches
sns.heatmap(similarity_matrix, cbar = True,  square = True, annot=False,annot_kws={'size': 15},  cmap= 'coolwarm')

# %%
with open('data/Much Ado about Nothing/all.log') as f:
    lines = f.readlines()

similarity_matrix = np.zeros([len(lines),len(lines)])
for i in range(len(lines)):
    for j in range(len(lines)):
        similarity_matrix[i,j] = metrics.pairwise.cosine_similarity(model.infer_vector(lines[i].split()).reshape(1, -1),model.infer_vector(lines[j].split()).reshape(1, -1))

pyplot.figure(figsize=(15, 15)) # width and height in inches
sns.heatmap(similarity_matrix, cbar = True,  square = True, annot=False,annot_kws={'size': 15},  cmap= 'coolwarm')

# %%
with open('data/Pericles, Prince of Tyre/all.log') as f:
    lines = f.readlines()

similarity_matrix = np.zeros([len(lines),len(lines)])
for i in range(len(lines)):
    for j in range(len(lines)):
        similarity_matrix[i,j] = metrics.pairwise.cosine_similarity(model.infer_vector(lines[i].split()).reshape(1, -1),model.infer_vector(lines[j].split()).reshape(1, -1))

pyplot.figure(figsize=(15, 15)) # width and height in inches
sns.heatmap(similarity_matrix, cbar = True,  square = True, annot=False,annot_kws={'size': 15},  cmap= 'coolwarm')

# %%
with open('data/The Comedy of Errors/all.log') as f:
    lines = f.readlines()

similarity_matrix = np.zeros([len(lines),len(lines)])
for i in range(len(lines)):
    for j in range(len(lines)):
        similarity_matrix[i,j] = metrics.pairwise.cosine_similarity(model.infer_vector(lines[i].split()).reshape(1, -1),model.infer_vector(lines[j].split()).reshape(1, -1))

pyplot.figure(figsize=(15, 15)) # width and height in inches
sns.heatmap(similarity_matrix, cbar = True,  square = True, annot=False,annot_kws={'size': 15},  cmap= 'coolwarm')

# %%
with open('data/The Famous History of the Life of Henry the Eighth/all.log') as f:
    lines = f.readlines()

similarity_matrix = np.zeros([len(lines),len(lines)])
for i in range(len(lines)):
    for j in range(len(lines)):
        similarity_matrix[i,j] = metrics.pairwise.cosine_similarity(model.infer_vector(lines[i].split()).reshape(1, -1),model.infer_vector(lines[j].split()).reshape(1, -1))

pyplot.figure(figsize=(15, 15)) # width and height in inches
sns.heatmap(similarity_matrix, cbar = True,  square = True, annot=False,annot_kws={'size': 15},  cmap= 'coolwarm')

# %%
with open('data/The First Part of Henry the Fourth/all.log') as f:
    lines = f.readlines()

similarity_matrix = np.zeros([len(lines),len(lines)])
for i in range(len(lines)):
    for j in range(len(lines)):
        similarity_matrix[i,j] = metrics.pairwise.cosine_similarity(model.infer_vector(lines[i].split()).reshape(1, -1),model.infer_vector(lines[j].split()).reshape(1, -1))

pyplot.figure(figsize=(15, 15)) # width and height in inches
sns.heatmap(similarity_matrix, cbar = True,  square = True, annot=False,annot_kws={'size': 15},  cmap= 'coolwarm')

# %%
with open('data/The First Part of Henry the Sixth/all.log') as f:
    lines = f.readlines()

similarity_matrix = np.zeros([len(lines),len(lines)])
for i in range(len(lines)):
    for j in range(len(lines)):
        similarity_matrix[i,j] = metrics.pairwise.cosine_similarity(model.infer_vector(lines[i].split()).reshape(1, -1),model.infer_vector(lines[j].split()).reshape(1, -1))

pyplot.figure(figsize=(15, 15)) # width and height in inches
sns.heatmap(similarity_matrix, cbar = True,  square = True, annot=False,annot_kws={'size': 15},  cmap= 'coolwarm')

# %%
with open('data/The History of Troilus and Cressida/all.log') as f:
    lines = f.readlines()

similarity_matrix = np.zeros([len(lines),len(lines)])
for i in range(len(lines)):
    for j in range(len(lines)):
        similarity_matrix[i,j] = metrics.pairwise.cosine_similarity(model.infer_vector(lines[i].split()).reshape(1, -1),model.infer_vector(lines[j].split()).reshape(1, -1))

pyplot.figure(figsize=(15, 15)) # width and height in inches
sns.heatmap(similarity_matrix, cbar = True,  square = True, annot=False,annot_kws={'size': 15},  cmap= 'coolwarm')

# %%
with open('data/The Life and Death of King John/all.log') as f:
    lines = f.readlines()

similarity_matrix = np.zeros([len(lines),len(lines)])
for i in range(len(lines)):
    for j in range(len(lines)):
        similarity_matrix[i,j] = metrics.pairwise.cosine_similarity(model.infer_vector(lines[i].split()).reshape(1, -1),model.infer_vector(lines[j].split()).reshape(1, -1))

pyplot.figure(figsize=(15, 15)) # width and height in inches
sns.heatmap(similarity_matrix, cbar = True,  square = True, annot=False,annot_kws={'size': 15},  cmap= 'coolwarm')

# %%
with open('data/The Life of Henry the Fifth/all.log') as f:
    lines = f.readlines()

similarity_matrix = np.zeros([len(lines),len(lines)])
for i in range(len(lines)):
    for j in range(len(lines)):
        similarity_matrix[i,j] = metrics.pairwise.cosine_similarity(model.infer_vector(lines[i].split()).reshape(1, -1),model.infer_vector(lines[j].split()).reshape(1, -1))

pyplot.figure(figsize=(15, 15)) # width and height in inches
sns.heatmap(similarity_matrix, cbar = True,  square = True, annot=False,annot_kws={'size': 15},  cmap= 'coolwarm')

# %%
with open('data/The Life of Timon of Athens/all.log') as f:
    lines = f.readlines()

similarity_matrix = np.zeros([len(lines),len(lines)])
for i in range(len(lines)):
    for j in range(len(lines)):
        similarity_matrix[i,j] = metrics.pairwise.cosine_similarity(model.infer_vector(lines[i].split()).reshape(1, -1),model.infer_vector(lines[j].split()).reshape(1, -1))

pyplot.figure(figsize=(15, 15)) # width and height in inches
sns.heatmap(similarity_matrix, cbar = True,  square = True, annot=False,annot_kws={'size': 15},  cmap= 'coolwarm')

# %%
with open('data/The Merchant of Venice/all.log') as f:
    lines = f.readlines()

similarity_matrix = np.zeros([len(lines),len(lines)])
for i in range(len(lines)):
    for j in range(len(lines)):
        similarity_matrix[i,j] = metrics.pairwise.cosine_similarity(model.infer_vector(lines[i].split()).reshape(1, -1),model.infer_vector(lines[j].split()).reshape(1, -1))

pyplot.figure(figsize=(15, 15)) # width and height in inches
sns.heatmap(similarity_matrix, cbar = True,  square = True, annot=False,annot_kws={'size': 15},  cmap= 'coolwarm')

# %%
with open('data/The Merry Wives of Windsor/all.log') as f:
    lines = f.readlines()

similarity_matrix = np.zeros([len(lines),len(lines)])
for i in range(len(lines)):
    for j in range(len(lines)):
        similarity_matrix[i,j] = metrics.pairwise.cosine_similarity(model.infer_vector(lines[i].split()).reshape(1, -1),model.infer_vector(lines[j].split()).reshape(1, -1))

pyplot.figure(figsize=(15, 15)) # width and height in inches
sns.heatmap(similarity_matrix, cbar = True,  square = True, annot=False,annot_kws={'size': 15},  cmap= 'coolwarm')

# %%
with open('data/The Second Part of Henry the Fourth/all.log') as f:
    lines = f.readlines()

similarity_matrix = np.zeros([len(lines),len(lines)])
for i in range(len(lines)):
    for j in range(len(lines)):
        similarity_matrix[i,j] = metrics.pairwise.cosine_similarity(model.infer_vector(lines[i].split()).reshape(1, -1),model.infer_vector(lines[j].split()).reshape(1, -1))

pyplot.figure(figsize=(15, 15)) # width and height in inches
sns.heatmap(similarity_matrix, cbar = True,  square = True, annot=False,annot_kws={'size': 15},  cmap= 'coolwarm')

# %%
with open('data/The Second Part of Henry the Sixth/all.log') as f:
    lines = f.readlines()

similarity_matrix = np.zeros([len(lines),len(lines)])
for i in range(len(lines)):
    for j in range(len(lines)):
        similarity_matrix[i,j] = metrics.pairwise.cosine_similarity(model.infer_vector(lines[i].split()).reshape(1, -1),model.infer_vector(lines[j].split()).reshape(1, -1))

pyplot.figure(figsize=(15, 15)) # width and height in inches
sns.heatmap(similarity_matrix, cbar = True,  square = True, annot=False,annot_kws={'size': 15},  cmap= 'coolwarm')

# %%
with open('data/The Taming of the Shrew/all.log') as f:
    lines = f.readlines()

similarity_matrix = np.zeros([len(lines),len(lines)])
for i in range(len(lines)):
    for j in range(len(lines)):
        similarity_matrix[i,j] = metrics.pairwise.cosine_similarity(model.infer_vector(lines[i].split()).reshape(1, -1),model.infer_vector(lines[j].split()).reshape(1, -1))

pyplot.figure(figsize=(15, 15)) # width and height in inches
sns.heatmap(similarity_matrix, cbar = True,  square = True, annot=False,annot_kws={'size': 15},  cmap= 'coolwarm')

# %%
with open('data/The Tempest/all.log') as f:
    lines = f.readlines()

similarity_matrix = np.zeros([len(lines),len(lines)])
for i in range(len(lines)):
    for j in range(len(lines)):
        similarity_matrix[i,j] = metrics.pairwise.cosine_similarity(model.infer_vector(lines[i].split()).reshape(1, -1),model.infer_vector(lines[j].split()).reshape(1, -1))

pyplot.figure(figsize=(15, 15)) # width and height in inches
sns.heatmap(similarity_matrix, cbar = True,  square = True, annot=False,annot_kws={'size': 15},  cmap= 'coolwarm')

# %%
with open('data/The Third Part of Henry the Sixth/all.log') as f:
    lines = f.readlines()

similarity_matrix = np.zeros([len(lines),len(lines)])
for i in range(len(lines)):
    for j in range(len(lines)):
        similarity_matrix[i,j] = metrics.pairwise.cosine_similarity(model.infer_vector(lines[i].split()).reshape(1, -1),model.infer_vector(lines[j].split()).reshape(1, -1))

pyplot.figure(figsize=(15, 15)) # width and height in inches
sns.heatmap(similarity_matrix, cbar = True,  square = True, annot=False,annot_kws={'size': 15},  cmap= 'coolwarm')

# %%
with open('data/The Tragedy of Antony and Cleopatra/all.log') as f:
    lines = f.readlines()

similarity_matrix = np.zeros([len(lines),len(lines)])
for i in range(len(lines)):
    for j in range(len(lines)):
        similarity_matrix[i,j] = metrics.pairwise.cosine_similarity(model.infer_vector(lines[i].split()).reshape(1, -1),model.infer_vector(lines[j].split()).reshape(1, -1))

pyplot.figure(figsize=(15, 15)) # width and height in inches
sns.heatmap(similarity_matrix, cbar = True,  square = True, annot=False,annot_kws={'size': 15},  cmap= 'coolwarm')

# %%
with open('data/The Tragedy of Coriolanus/all.log') as f:
    lines = f.readlines()

similarity_matrix = np.zeros([len(lines),len(lines)])
for i in range(len(lines)):
    for j in range(len(lines)):
        similarity_matrix[i,j] = metrics.pairwise.cosine_similarity(model.infer_vector(lines[i].split()).reshape(1, -1),model.infer_vector(lines[j].split()).reshape(1, -1))

pyplot.figure(figsize=(15, 15)) # width and height in inches
sns.heatmap(similarity_matrix, cbar = True,  square = True, annot=False,annot_kws={'size': 15},  cmap= 'coolwarm')

# %%
with open('data/The Tragedy of Hamlet, Prince of Denmark/all.log') as f:
    lines = f.readlines()

similarity_matrix = np.zeros([len(lines),len(lines)])
for i in range(len(lines)):
    for j in range(len(lines)):
        similarity_matrix[i,j] = metrics.pairwise.cosine_similarity(model.infer_vector(lines[i].split()).reshape(1, -1),model.infer_vector(lines[j].split()).reshape(1, -1))

pyplot.figure(figsize=(15, 15)) # width and height in inches
sns.heatmap(similarity_matrix, cbar = True,  square = True, annot=False,annot_kws={'size': 15},  cmap= 'coolwarm')

# %%
with open('data/The Tragedy of Julius Caesar/all.log') as f:
    lines = f.readlines()

similarity_matrix = np.zeros([len(lines),len(lines)])
for i in range(len(lines)):
    for j in range(len(lines)):
        similarity_matrix[i,j] = metrics.pairwise.cosine_similarity(model.infer_vector(lines[i].split()).reshape(1, -1),model.infer_vector(lines[j].split()).reshape(1, -1))

pyplot.figure(figsize=(15, 15)) # width and height in inches
sns.heatmap(similarity_matrix, cbar = True,  square = True, annot=False,annot_kws={'size': 15},  cmap= 'coolwarm')

# %%
with open('data/The Tragedy of King Lear/all.log') as f:
    lines = f.readlines()

similarity_matrix = np.zeros([len(lines),len(lines)])
for i in range(len(lines)):
    for j in range(len(lines)):
        similarity_matrix[i,j] = metrics.pairwise.cosine_similarity(model.infer_vector(lines[i].split()).reshape(1, -1),model.infer_vector(lines[j].split()).reshape(1, -1))

pyplot.figure(figsize=(15, 15)) # width and height in inches
sns.heatmap(similarity_matrix, cbar = True,  square = True, annot=False,annot_kws={'size': 15},  cmap= 'coolwarm')

# %%
with open('data/The Tragedy of King Richard the Second/all.log') as f:
    lines = f.readlines()

similarity_matrix = np.zeros([len(lines),len(lines)])
for i in range(len(lines)):
    for j in range(len(lines)):
        similarity_matrix[i,j] = metrics.pairwise.cosine_similarity(model.infer_vector(lines[i].split()).reshape(1, -1),model.infer_vector(lines[j].split()).reshape(1, -1))

pyplot.figure(figsize=(15, 15)) # width and height in inches
sns.heatmap(similarity_matrix, cbar = True,  square = True, annot=False,annot_kws={'size': 15},  cmap= 'coolwarm')

# %%
with open('data/The Tragedy of Macbeth/all.log') as f:
    lines = f.readlines()

similarity_matrix = np.zeros([len(lines),len(lines)])
for i in range(len(lines)):
    for j in range(len(lines)):
        similarity_matrix[i,j] = metrics.pairwise.cosine_similarity(model.infer_vector(lines[i].split()).reshape(1, -1),model.infer_vector(lines[j].split()).reshape(1, -1))

pyplot.figure(figsize=(15, 15)) # width and height in inches
sns.heatmap(similarity_matrix, cbar = True,  square = True, annot=False,annot_kws={'size': 15},  cmap= 'coolwarm')

# %%
with open('data/The Tragedy of Othello, the Moor of Venice/all.log') as f:
    lines = f.readlines()

similarity_matrix = np.zeros([len(lines),len(lines)])
for i in range(len(lines)):
    for j in range(len(lines)):
        similarity_matrix[i,j] = metrics.pairwise.cosine_similarity(model.infer_vector(lines[i].split()).reshape(1, -1),model.infer_vector(lines[j].split()).reshape(1, -1))

pyplot.figure(figsize=(15, 15)) # width and height in inches
sns.heatmap(similarity_matrix, cbar = True,  square = True, annot=False,annot_kws={'size': 15},  cmap= 'coolwarm')

# %%
with open('data/The Tragedy of Richard the Third/all.log') as f:
    lines = f.readlines()

similarity_matrix = np.zeros([len(lines),len(lines)])
for i in range(len(lines)):
    for j in range(len(lines)):
        similarity_matrix[i,j] = metrics.pairwise.cosine_similarity(model.infer_vector(lines[i].split()).reshape(1, -1),model.infer_vector(lines[j].split()).reshape(1, -1))

pyplot.figure(figsize=(15, 15)) # width and height in inches
sns.heatmap(similarity_matrix, cbar = True,  square = True, annot=False,annot_kws={'size': 15},  cmap= 'coolwarm')

# %%
with open('data/The Tragedy of Romeo and Juliet/all.log') as f:
    lines = f.readlines()

similarity_matrix = np.zeros([len(lines),len(lines)])
for i in range(len(lines)):
    for j in range(len(lines)):
        similarity_matrix[i,j] = metrics.pairwise.cosine_similarity(model.infer_vector(lines[i].split()).reshape(1, -1),model.infer_vector(lines[j].split()).reshape(1, -1))

pyplot.figure(figsize=(15, 15)) # width and height in inches
sns.heatmap(similarity_matrix, cbar = True,  square = True, annot=False,annot_kws={'size': 15},  cmap= 'coolwarm')

# %%
with open('data/The Tragedy of Titus Andronicus/all.log') as f:
    lines = f.readlines()

similarity_matrix = np.zeros([len(lines),len(lines)])
for i in range(len(lines)):
    for j in range(len(lines)):
        similarity_matrix[i,j] = metrics.pairwise.cosine_similarity(model.infer_vector(lines[i].split()).reshape(1, -1),model.infer_vector(lines[j].split()).reshape(1, -1))

pyplot.figure(figsize=(15, 15)) # width and height in inches
sns.heatmap(similarity_matrix, cbar = True,  square = True, annot=False,annot_kws={'size': 15},  cmap= 'coolwarm')

# %%
with open('data/The Two Gentlemen of Verona/all.log') as f:
    lines = f.readlines()

similarity_matrix = np.zeros([len(lines),len(lines)])
for i in range(len(lines)):
    for j in range(len(lines)):
        similarity_matrix[i,j] = metrics.pairwise.cosine_similarity(model.infer_vector(lines[i].split()).reshape(1, -1),model.infer_vector(lines[j].split()).reshape(1, -1))

pyplot.figure(figsize=(15, 15)) # width and height in inches
sns.heatmap(similarity_matrix, cbar = True,  square = True, annot=False,annot_kws={'size': 15},  cmap= 'coolwarm')

# %%
with open('data/The Winter\'s Tale/all.log') as f:
    lines = f.readlines()

similarity_matrix = np.zeros([len(lines),len(lines)])
for i in range(len(lines)):
    for j in range(len(lines)):
        similarity_matrix[i,j] = metrics.pairwise.cosine_similarity(model.infer_vector(lines[i].split()).reshape(1, -1),model.infer_vector(lines[j].split()).reshape(1, -1))

pyplot.figure(figsize=(15, 15)) # width and height in inches
sns.heatmap(similarity_matrix, cbar = True,  square = True, annot=False,annot_kws={'size': 15},  cmap= 'coolwarm')

# %%
with open('data/Twelfth Night, or What You Will/all.log') as f:
    lines = f.readlines()

similarity_matrix = np.zeros([len(lines),len(lines)])
for i in range(len(lines)):
    for j in range(len(lines)):
        similarity_matrix[i,j] = metrics.pairwise.cosine_similarity(model.infer_vector(lines[i].split()).reshape(1, -1),model.infer_vector(lines[j].split()).reshape(1, -1))

pyplot.figure(figsize=(15, 15)) # width and height in inches
sns.heatmap(similarity_matrix, cbar = True,  square = True, annot=False,annot_kws={'size': 15},  cmap= 'coolwarm')

# %% [raw]
# np.savetxt("similarity_matrix.csv", similarity_matrix, delimiter=";")

# %% [markdown]
# Conclusion
# ----------
#
# Let's review what we've seen in this tutorial:
#
# 0. Review the relevant models: bag-of-words, Word2Vec, Doc2Vec
# 1. Load and preprocess the training and test corpora (see `core_concepts_corpus`)
# 2. Train a Doc2Vec `core_concepts_model` model using the training corpus
# 3. Demonstrate how the trained model can be used to infer a `core_concepts_vector`
# 4. Assess the model
# 5. Test the model on the test corpus
#
# That's it! Doc2Vec is a great way to explore relationships between documents.
#
# Additional Resources
# --------------------
#
# If you'd like to know more about the subject matter of this tutorial, check out the links below.
#
# * `Word2Vec Paper <https://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf>`_
# * `Doc2Vec Paper <https://cs.stanford.edu/~quocle/paragraph_vector.pdf>`_
# * `Dr. Michael D. Lee's Website <http://faculty.sites.uci.edu/mdlee>`_
# * `Lee Corpus <http://faculty.sites.uci.edu/mdlee/similarity-data/>`__
# * `IMDB Doc2Vec Tutorial <doc2vec-IMDB.ipynb>`_
